# %%
# https://www.gw-openscience.org/events/GW150914/
# Gravitational-wave strain projected onto each detector in the 35–350 Hz band.

# %%
import pandas as pd

# %%
hfile = pd.read_table("/Users/shu-wei/Desktop/GW150914/fig1_waveform_H.txt", sep = ';')
hfile
# Out:
#               # time (seconds)           strain * 1.e21
# 0     2.500497972500000388e-01 4.825775534740658250e-04
# 1     2.501108324062500388e-01 3.430744407868812945e-04
# 2     2.501718675625000388e-01 2.760189745234001269e-04
# 3     2.502329027187500388e-01 2.820404899486351601e-04
# 4     2.502939378750000388e-01 3.615077713955138243e-04
# ...                                                 ...
# 3435  4.597055589687500388e-01 1.046402979825213631e-01
# 3436  4.597665941250000388e-01 1.033879748890068756e-01
# 3437  4.598276292812500388e-01 1.019777783055595133e-01
# 3438  4.598886644375000388e-01 1.004183251046691094e-01
# 3439  4.599496995937500388e-01 9.871888755616879674e-02
#
# [3440 rows x 1 columns]

# %%
hfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3440 entries, 0 to 3439
# Data columns (total 1 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   # time (seconds)           strain * 1.e21  3440 non-null   object
# dtypes: object(1)
# memory usage: 27.0+ KB

# %%
lfile = pd.read_table("/Users/shu-wei/Desktop/GW150914/fig1_waveform_L.txt", sep = ';')
lfile
# Out:
#               # time (seconds)           strain * 1.e21
# 0     2.500078050625000325e-01 3.112705760860156809e-02
# 1     2.500688402187500325e-01 2.996694418865552059e-02
# 2     2.501298753750000325e-01 2.880054172868640183e-02
# 3     2.501909105312500325e-01 2.763297889754109254e-02
# 4     2.502519456875000325e-01 2.646941272694218819e-02
# ...                                                 ...
# 3436  4.597246019375000325e-01 1.215493904453295373e-02
# 3437  4.597856370937500325e-01 1.104040262020537615e-02
# 3438  4.598466722500000325e-01 9.822500632612208779e-03
# 3439  4.599077074062500325e-01 8.502757517591713957e-03
# 3440  4.599687425625000325e-01 7.083510154960930699e-03
#
# [3441 rows x 1 columns]

# %%
lfile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3441 entries, 0 to 3440
# Data columns (total 1 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   # time (seconds)           strain * 1.e21  3441 non-null   object
# dtypes: object(1)
# memory usage: 27.0+ KB

# %%
f = open("/Users/shu-wei/Desktop/GW150914/fig1_waveform_H.txt")

# %%
# %time

import numpy as np

f = open("/Users/shu-wei/Desktop/GW150914/fig1_waveform_H.txt")
list_t = []
list_hstrain = []
for line in f.readlines():
#     print(line)
#     print(line[0])
#     print("######")
    s = line.split(' ')
#     print(len(s))
#     print(s)
    list_t.append(s[0])
    list_hstrain.append(s[1].rstrip())
    
f.close()

list_t = np.array(list_t[1:]).astype(np.float)
list_hstrain = np.array(list_hstrain[1:]).astype(np.float)


#np.savez_compressed("/Users/shu-wei/Desktop/GW150914/fig1_observed_H", T = list_t, Strain = list_strain, information=["H1"])
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 9.06 µs
# <ipython-input-46-5b6de2ed065e>:20: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   list_t = np.array(list_t[1:]).astype(np.float)
# <ipython-input-46-5b6de2ed065e>:21: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   list_hstrain = np.array(list_hstrain[1:]).astype(np.float)

# %%
# file = np.load("")
# file.files

# list_t = file["T"]
# list_strain = file["Strain"]

import matplotlib.pyplot as plt

plt.plot(list_t[:], list_hstrain[:], 'b')
plt.xlabel('GPS Time (s)')
plt.ylabel('H1 Strain, 4096 HZ, GW150914')

plt.show()

# %%
f = open("/Users/shu-wei/Desktop/GW150914/fig1_waveform_L.txt")

# %%
# %time

import numpy as np

f = open("/Users/shu-wei/Desktop/GW150914/fig1_waveform_L.txt")
list_t = []
list_lstrain = []
for line in f.readlines():
#     print(line)
#     print(line[0])
#     print("######")
    s = line.split(' ')
#     print(len(s))
#     print(s)
    list_t.append(s[0])
    list_lstrain.append(s[1].rstrip())
    
f.close()

list_t = np.array(list_t[1:]).astype(np.float)
list_lstrain = np.array(list_lstrain[1:]).astype(np.float)


#np.savez_compressed("/Users/shu-wei/Desktop/GW150914/fig1_observed_H", T = list_t, Strain = list_strain, information=["H1"])
# Out:
# CPU times: user 6 µs, sys: 1e+03 ns, total: 7 µs
# Wall time: 16 µs
# <ipython-input-49-27d98c42fcd3>:20: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   list_t = np.array(list_t[1:]).astype(np.float)
# <ipython-input-49-27d98c42fcd3>:21: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   list_lstrain = np.array(list_lstrain[1:]).astype(np.float)

# %%
# file = np.load("")
# file.files

# list_t = file["T"]
# list_strain = file["Strain"]

import matplotlib.pyplot as plt

plt.plot(list_t[:], list_lstrain[:], 'r')
plt.xlabel('GPS Time (s)')
plt.ylabel('L1 Strain, 4096 HZ, GW150914')

plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# import matplotlib.pyplot as plt
# import matplotlib.mlab as mlab

# plt.figure(figsize=(10,8))

# plt.plot(list_t[:], list_hstrain[:], 'b', label='H1 strain')
# plt.plot(list_t[:], list_lstrain[:], 'r', label='L1 strain')
# plt.xlabel('GPS Time (s)')
# plt.ylabel('H1 and L1 Strain, 4096 HZ, GW150914')

# plt.show()
