# %%
# This notebook provides a quick look at short segments of data from the 
# GWOSC (https://gw-osc.org/)
# https://www.gw-openscience.org/events/GW150914/
# https://www.gw-openscience.org/s/sample_code/plot_strain.py
# https://www.gw-openscience.org/tutorial02/
# Set the GPS time (t0) and detector in the first cell

# %%
#-------------------------
# Open the File
#-------------------------
fileName = '/Users/shu-wei/Desktop/GW150914/H-H1_LOSC_4_V2-1126257414-4096.hdf5'
dataFile = h5py.File('/Users/shu-wei/Desktop/GW150914/H-H1_LOSC_4_V2-1126257414-4096.hdf5', 'r')

# %%
# -- Read strain data
strain = dataFile['strain']['Strain'].value
ts = dataFile['strain']['Strain'].attrs['Xspacing']
# Out:
# <ipython-input-61-3316fa6f47dd>:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   strain = dataFile['strain']['Strain'].value

# %%
#-----------------------
# Read in some meta data
#-----------------------
metaKeys = list(dataFile['meta'].keys())
meta = dataFile['meta']
#print("\n\n")
for key in metaKeys:
    print(key, meta[key].value)
# Out:
# Description b'Strain data time series from LIGO'
# DescriptionURL b'http://losc.ligo.org/'
# Detector b'H1'
# Duration 4096
# GPSstart 1126257414
# Observatory b'H'
# Type b'StrainTimeSeries'
# UTCstart b'2015-09-14T09:16:37'
# <ipython-input-62-fb8a8de914e3>:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   print(key, meta[key].value)

# %%
gpsStart = meta['GPSstart'].value
duration = meta['Duration'].value
gpsEnd   = gpsStart + duration
detector = meta['Detector']
# Out:
# <ipython-input-63-e1fa4edc76f8>:1: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   gpsStart = meta['GPSstart'].value
# <ipython-input-63-e1fa4edc76f8>:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   duration = meta['Duration'].value

# %%
print(gpsStart)
print(gpsEnd)
print(duration)
# Out:
# 1126257414
# 1126261510
# 4096

# %%
#---------------------------
# Create a time vector
#---------------------------
time = np.arange(gpsStart, gpsEnd, ts)
print(time)
# Out:
# [1.12625741e+09 1.12625741e+09 1.12625741e+09 ... 1.12626151e+09
#  1.12626151e+09 1.12626151e+09]

# %%
#----------------------
# Plot the time series
#----------------------
# %time
plt.figure(figsize=(6,4))
numSamples = 10000
plt.plot(time[0:numSamples], strain[0:numSamples])
plt.xlabel('GPS Time (s)')
plt.ylabel('H1 Strain, 4096 HZ, GW150914')
plt.show()
# Out:
# CPU times: user 8 µs, sys: 1 µs, total: 9 µs
# Wall time: 17.9 µs

# %%
import numpy as np
import pylab as plt
import h5py

# %%
#-------------------------
# Open the File
#-------------------------
fileName = 'L-L1_LOSC_4_V2-1126257414-4096.hdf5'
dataFile = h5py.File('/Users/shu-wei/Desktop/GW150914/L-L1_LOSC_4_V2-1126257414-4096.hdf5', 'r')

# %%
# -- Read strain data
strain = dataFile['strain']['Strain'].value
ts = dataFile['strain']['Strain'].attrs['Xspacing']
# Out:
# <ipython-input-70-3316fa6f47dd>:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   strain = dataFile['strain']['Strain'].value

# %%
#-----------------------
# Read in some meta data
#-----------------------
metaKeys = list(dataFile['meta'].keys())
meta = dataFile['meta']
#print("\n\n")
for key in metaKeys:
    print(key, meta[key].value)
# Out:
# Description b'Strain data time series from LIGO'
# DescriptionURL b'http://losc.ligo.org/'
# Detector b'L1'
# Duration 4096
# GPSstart 1126257414
# Observatory b'L'
# Type b'StrainTimeSeries'
# UTCstart b'2015-09-14T09:16:37'
# <ipython-input-71-fb8a8de914e3>:8: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   print(key, meta[key].value)

# %%
gpsStart = meta['GPSstart'].value
duration = meta['Duration'].value
gpsEnd   = gpsStart + duration
detector = meta['Detector']
# Out:
# <ipython-input-72-e1fa4edc76f8>:1: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   gpsStart = meta['GPSstart'].value
# <ipython-input-72-e1fa4edc76f8>:2: H5pyDeprecationWarning: dataset.value has been deprecated. Use dataset[()] instead.
#   duration = meta['Duration'].value

# %%
print(gpsStart)
print(gpsEnd)
print(duration)
# Out:
# 1126257414
# 1126261510
# 4096

# %%
#---------------------------
# Create a time vector
#---------------------------
time = np.arange(gpsStart, gpsEnd, ts)
print(time)
# Out:
# [1.12625741e+09 1.12625741e+09 1.12625741e+09 ... 1.12626151e+09
#  1.12626151e+09 1.12626151e+09]

# %%
#----------------------
# Plot the time series
#----------------------
# %time
plt.figure(figsize=(6,4))
numSamples = 10000
plt.plot(time[0:numSamples], strain[0:numSamples])
plt.xlabel('GPS Time (s)')
plt.ylabel('L1 Strain, 4096 HZ, GW150914')
plt.show()
# Out:
# CPU times: user 6 µs, sys: 0 ns, total: 6 µs
# Wall time: 12.6 µs
