# %%
# https://www.gw-openscience.org/events/GW150914/

# %%
import pandas as pd

# %%
htxtfile = pd.read_table("/Users/shu-wei/Desktop/GW150914/H1_GDS_CALIB_STRAIN.txt")
htxtfile
# Out:
#        # frequency (Hz)       Amplitude spectral density
# 0      1.250000000000000000e-01 3.557569735685248914e-19
# 1      2.500000000000000000e-01 3.748115437054243309e-19
# 2      3.750000000000000000e-01 2.638520904054861846e-19
# 3      5.000000000000000000e-01 1.268281879605441188e-19
# 4      6.250000000000000000e-01 4.338996110913581744e-20
# ...                                                  ...
# 65531  8.191500000000000000e+03 4.168263686062537058e-28
# 65532  8.191625000000000000e+03 6.825672582886520103e-28
# 65533  8.191750000000000000e+03 7.570526573813162824e-28
# 65534  8.191875000000000000e+03 6.983421916957209060e-28
# 65535  8.192000000000000000e+03 3.827202896145776481e-28
#
# [65536 rows x 1 columns]

# %%
f = open("/Users/shu-wei/Desktop/GW150914/H1_GDS_CALIB_STRAIN.txt")

# %%
# %time

import numpy as np

f = open("/Users/shu-wei/Desktop/GW150914/H1_GDS_CALIB_STRAIN.txt")
list_f = []
list_hasd = []
for line in f.readlines():
#     print(line)
#     print(line[0])
#     print("######")
    s = line.split(' ')
#     print(len(s))
#     print(s)
    list_f.append(s[0])
    list_hasd.append(s[1].rstrip())
    
f.close()

list_f = np.array(list_f[1:]).astype(np.float)
list_hasd = np.array(list_hasd[1:]).astype(np.float)

# np.savez_compressed("", T = list_t, Strain = list_strain, information=[""])
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 3.81 µs
# <ipython-input-44-104a40dced05>:20: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   list_f = np.array(list_f[1:]).astype(np.float)
# <ipython-input-44-104a40dced05>:21: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
# file = np.load("")
# file.files

# list_t = file["T"]
# list_strain = file["Strain"]

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.figure(figsize=(10,8))
plt.loglog(list_f[:], np.sqrt(list_hasd[:]), 'r', label='H1 strain')

plt.xlabel('Freq (Hz)')
plt.ylabel('ASD (strain/rtHz)')
plt.show()

# %%
f = open("/Users/shu-wei/Desktop/GW150914/L1_GDS_CALIB_STRAIN.txt")

# %%
# %time

import numpy as np

f = open("/Users/shu-wei/Desktop/GW150914/L1_GDS_CALIB_STRAIN.txt")
list_f = []
list_lasd = []
for line in f.readlines():
#     print(line)
#     print(line[0])
#     print("######")
    s = line.split(' ')
#     print(len(s))
#     print(s)
    list_f.append(s[0])
    list_lasd.append(s[1].rstrip())
    
f.close()

list_f = np.array(list_f[1:]).astype(np.float)
list_lasd = np.array(list_lasd[1:]).astype(np.float)

# np.savez_compressed("", T = list_t, Strain = list_strain, information=[""])
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 1.91 µs
# <ipython-input-47-901dbe92597a>:20: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   list_f = np.array(list_f[1:]).astype(np.float)
# <ipython-input-47-901dbe92597a>:21: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.figure(figsize=(10,8))

plt.loglog(list_f[:], np.sqrt(list_lasd[:]), 'b', label='L1 strain')
plt.ylabel('ASD (strain/rtHz)')
plt.xlabel('Freq (Hz)')

plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab

plt.figure(figsize=(10,8))

plt.loglog(list_f[:], np.sqrt(list_hasd[:]), 'b', label='H1 strain')
plt.loglog(list_f[:], np.sqrt(list_lasd[:]), 'r', label='L1 strain')
# plt.loglog(list_f[:], list_lasd[:], 'b', label='L1 strain')
#plt.loglog()
plt.ylabel('ASD (strain/rtHz)')
plt.xlabel('Freq (Hz)')

plt.show()
